# %%
from cosi_data_helper import *
from plotting_helper import *

# %%
#read in files and use above function to make them into a dataframe
#CS 137
#pre radiation Cs137
pre_rad_Cs = [ "pre_rad_dats/20231003_Cs137_AC_600V_1.dat", "pre_rad_dats/20231011_Cs137_AC_600V.dat", "pre_rad_dats/20231003_Cs137_AC_600V_2.dat", "pre_rad_dats/20231020_Cs137_AC_600V.dat", "pre_rad_dats/20230927_Cs137_DC_600V.dat", "pre_rad_dats/20231006_Cs137_DC_600V_1.dat", "pre_rad_dats/20231006_Cs137_DC_600V_2.dat" , "pre_rad_dats/20231023_Cs137_DC_600V.dat"]
# "pre_rad_dats/20230925_Cs137_DC_600V.dat",
pre_rad_data_Cs = make_df_from_dat(pre_rad_Cs, 400, 700)
pre_rad_Cs_AC =["pre_rad_dats/20231003_Cs137_AC_600V_1.dat", "pre_rad_dats/20231011_Cs137_AC_600V.dat", "pre_rad_dats/20231003_Cs137_AC_600V_2.dat", "pre_rad_dats/20231020_Cs137_AC_600V.dat"]
pre_rad_Cs_DC =["pre_rad_dats/20230925_Cs137_DC_600V.dat", "pre_rad_dats/20230927_Cs137_DC_600V.dat", "pre_rad_dats/20231006_Cs137_DC_600V_1.dat", "pre_rad_dats/20231006_Cs137_DC_600V_2.dat" , "pre_rad_dats/20231023_Cs137_DC_600V.dat"]
#pre_rad_data_Cs_AC =make_df_from_dat(pre_rad_Cs_AC)
#pre_rad_data_Cs_DC =make_df_from_dat(pre_rad_Cs_DC)

#adjust which data set you are fitting here 

pre_rad_data = pre_rad_data_Cs
#pre rad AC and DC strips
pre_rad_ACstrips = pre_rad_data.iloc[:,3]
pre_rad_DCstrips = pre_rad_data.iloc[:,6]

# %%
#post radiation2 Cs137
post_rad2_Cs = ["post_rad2_dats/20231120_Cs137_AC_600V.dat","post_rad2_dats/20231122_Cs137_DC_600V.dat", "post_rad2_dats/20231127_Cs137_AC_600V.dat", "post_rad2_dats/20231128_Cs137_DC_600V.dat", "post_rad2_dats/20231129_Cs137_DC_600V.dat", "post_rad2_dats/20231130_Cs137_DC_600V.dat","post_rad2_dats/20231201_Cs137_DC_600V.dat", "post_rad2_dats/20231204_Cs137_AC_600V.dat", "post_rad2_dats/20231205_Cs137_AC_600V.dat", "post_rad2_dats/20231206_Cs137_AC_600V.dat", "post_rad2_dats/20231207_Cs137_AC_600V.dat", "post_rad2_dats/20231208_Cs137_AC_600V.dat"]  #"post_rad2_dats/20231213_Cs241_AC_600V.dat", "post_rad2_dats/20231214_Cs241_DC_600V.dat", "post_rad2_dats/20231215_Cs137_DC_600V.dat"] #"post_rad2_dats/20231212_Cs241_AC_600V.dat",
post_rad2_data_Cs = make_df_from_dat(post_rad2_Cs, 400, 700)
post_rad2_Cs_AC = ["post_rad2_dats/20231120_Cs137_AC_600V.dat", "post_rad2_dats/20231127_Cs137_AC_600V.dat", "post_rad2_dats/20231204_Cs137_AC_600V.dat", "post_rad2_dats/20231205_Cs137_AC_600V.dat", "post_rad2_dats/20231206_Cs137_AC_600V.dat", "post_rad2_dats/20231207_Cs137_AC_600V.dat", "post_rad2_dats/20231208_Cs137_AC_600V.dat"]
post_rad2_Cs_DC =["post_rad2_dats/20231122_Cs137_DC_600V.dat","post_rad2_dats/20231128_Cs137_DC_600V.dat", "post_rad2_dats/20231129_Cs137_DC_600V.dat", "post_rad2_dats/20231130_Cs137_DC_600V.dat","post_rad2_dats/20231201_Cs137_DC_600V.dat"]
#post_rad2_data_Cs_AC = make_df_from_dat(post_rad2_Cs_AC, 600, 700)
#post_rad2_data_Cs_DC = make_df_from_dat(post_rad2_Cs_DC, 600, 700)

# %%
#post rad 1 Cs137
post_rad1_Cs = ["post_rad_dats/20231102_Cs137_AC_600V_1.dat","post_rad_dats/20231102_Cs137_AC_600V_2.dat", "post_rad_dats/20231101_Cs137_AC_600V.dat", "post_rad_dats/20231031_Cs137_AC_600V.dat", "post_rad_dats/20231030_Cs137_AC_600V.dat", "post_rad_dats/20231102_Cs137_AC_600V_1.dat","post_rad_dats/20231102_Cs137_DC_600V.dat", "post_rad_dats/20231102_Cs137_AC_600V_2.dat", "post_rad_dats/20231031_Cs137_AC_600V.dat", "post_rad_dats/20231031_Cs137_DC_600V.dat", "post_rad_dats/20231030_Cs137_DC_600V_1.dat", "post_rad_dats/20231030_Cs137_DC_600V_1.dat", "post_rad_dats/20231030_Cs137_DC_600V_2.dat", "post_rad_dats/20231030_Cs137_AC_600V.dat"]
post_rad1_data_Cs = make_df_from_dat(post_rad1_Cs,400, 700)
post_rad1_Cs_AC = ["post_rad_dats/20231102_Cs137_AC_600V_1.dat","post_rad_dats/20231102_Cs137_AC_600V_2.dat", "post_rad_dats/20231101_Cs137_AC_600V.dat", "post_rad_dats/20231031_Cs137_AC_600V.dat", "post_rad_dats/20231030_Cs137_AC_600V.dat", "post_rad_dats/20231102_Cs137_AC_600V_1.dat", "post_rad_dats/20231030_Cs137_AC_600V.dat",  "post_rad_dats/20231102_Cs137_AC_600V_2.dat", "post_rad_dats/20231031_Cs137_AC_600V.dat"]
post_rad1_Cs_DC = ["post_rad_dats/20231102_Cs137_DC_600V.dat", "post_rad_dats/20231031_Cs137_DC_600V.dat", "post_rad_dats/20231030_Cs137_DC_600V_1.dat", "post_rad_dats/20231030_Cs137_DC_600V_1.dat", "post_rad_dats/20231030_Cs137_DC_600V_2.dat"]
#post_rad1_data_Cs_AC = make_df_from_dat(post_rad1_Cs_AC,600, 700)
#post_rad1_data_Cs_DC = make_df_from_dat(post_rad1_Cs_DC, 600, 700)

# %%
#room temp anneal Cs137
roomtempanneal_Cs = ["roomtemp_anneal/20240122_Cs137_AC_600V.dat","roomtemp_anneal/20240117_Cs137_AC_600V.dat","roomtemp_anneal/20240124_Cs137_DC_600V.dat","roomtemp_anneal/20240126_Cs137_DC_600V.dat", "roomtemp_anneal/20240119_Cs137_AC_600V.dat", "roomtemp_anneal/20240123_Cs137_AC_600V.dat", "roomtemp_anneal/20240125_Cs137_DC_600V.dat"]
roomtempanneal_data_Cs = make_df_from_dat(roomtempanneal_Cs, 400, 700)
roomtempanneal_Cs_AC=["roomtemp_anneal/20240122_Cs137_AC_600V.dat","roomtemp_anneal/20240117_Cs137_AC_600V.dat","roomtemp_anneal/20240119_Cs137_AC_600V.dat", "roomtemp_anneal/20240123_Cs137_AC_600V.dat"]
roomtempanneal_Cs_DC =["roomtemp_anneal/20240124_Cs137_DC_600V.dat","roomtemp_anneal/20240126_Cs137_DC_600V.dat","roomtemp_anneal/20240125_Cs137_DC_600V.dat"]
roomtempanneal_Cs_data_AC = make_df_from_dat(roomtempanneal_Cs_AC, 550, 700)
roomtempanneal_Cs_data_DC = make_df_from_dat(roomtempanneal_Cs_DC, 550, 700)

# %%
#post anneal 1 data Cs137
post_anneal1_Cs = ["post_anneal1_dats/20240312_Cs137_AC_600V.dat", "post_anneal1_dats/20240313_Cs137_DC_600V.dat",  "post_anneal1_dats/20240314_Cs137_AC_600V.dat"]
post_anneal1_data_Cs = make_df_from_dat(post_anneal1_Cs,600, 700)
post_anneal1_Cs_AC =["post_anneal1_dats/20240312_Cs137_AC_600V.dat", "post_anneal1_dats/20240314_Cs137_Ac_600V.dat"]
post_anneal1_Cs_DC =["post_anneal1_dats/20240313_Cs137_DC_600V.dat"]
post_anneal1_data_Cs_AC = make_df_from_dat(post_anneal1_Cs_AC, 600, 700)
post_anneal1_data_Cs_DC = make_df_from_dat(post_anneal1_Cs_DC, 600, 700)

# %%
#post anneal 2 data Cs137
post_anneal2_Cs = ["post_anneal2_dats/20240321_Cs137_AC_600V.dat", "post_anneal2_dats/20240322_Cs137_AC_600V.dat"]#, "post_anneal2_dats/20240322_Cs137_AC_600V.dat"]
post_anneal2_data_Cs = make_df_from_dat(post_anneal2_Cs, 600, 700)
post_anneal2_data_Cs_AC = post_anneal2_data_Cs

# %%
#post anneal 3 data Cs137
post_anneal3_Cs = ["postanneal3_dats/20240328_Cs137_AC_600V.dat"]
post_anneal3_data_Cs = make_df_from_dat(post_anneal3_Cs, 600, 700)
post_anneal3_data_Cs_AC = post_anneal3_data_Cs

# %%
#post anneal 4 data Cs137
post_anneal4_Cs = ["postanneal4_dats/20240404_Cs137_AC_600V.dat", "postanneal4_dats/20240411_Cs137_DC_600V.dat", "postanneal4_dats/20240410_Cs137_AC_600V.dat"]
post_anneal4_data_Cs = make_df_from_dat(post_anneal4_Cs, 600, 700)
post_anneal4_Cs_AC =["postanneal4_dats/20240404_Cs137_AC_600V.dat","postanneal4_dats/20240410_Cs137_AC_600V.dat"]
post_anneal4_Cs_DC =["postanneal4_dats/20240411_Cs137_DC_600V.dat"]
post_anneal4_data_Cs_AC = make_df_from_dat(post_anneal4_Cs_AC, 0, 691.5)
post_anneal4_data_Cs_DC = make_df_from_dat(post_anneal4_Cs_DC, 0, 691.5)

# %%
#post anneal 5 data Cs137
post_anneal5_Cs = ["postanneal5_dats/20240422_Cs137_AC_600V.dat", "postanneal5_dats/20240423_Cs137_DC_600V.dat"]
post_anneal5_data_Cs = make_df_from_dat(post_anneal5_Cs,600, 700)
post_anneal5_Cs_AC = ["postanneal5_dats/20240422_Cs137_AC_600V.dat"]
post_anneal5_Cs_DC = ["postanneal5_dats/20240423_Cs137_DC_600V.dat"]
#post_anneal5_data_Cs_AC = make_df_from_dat(post_anneal5_Cs_AC,0, 691.5)
#post_anneal5_data_Cs_DC = make_df_from_dat(post_anneal5_Cs_DC, 0, 691.5)

# %%
#post anneal 6 data Cs137
post_anneal6_Cs = ["postanneal6_dats/20240503_Cs137_AC_600V.dat", "postanneal6_dats/20240513_Cs137_AC_600V.dat"] #, "postanneal6_dats/20240513_Cs137_AC_600V.dat"
post_anneal6_data_Cs = make_df_from_dat(post_anneal6_Cs, 600, 700)

# %%
#post anneal 7 data 
post_anneal7_Cs = ["postanneal7_dats/20240530_Cs137_AC_600V.dat"]
post_anneal7_data_Cs = make_df_from_dat(post_anneal7_Cs, 600, 700)

# %%
#second room temp anneals 
roomtemp_anneal2_1_Cs = ["roomtemp_anneal2/20241009_Cs137_AC_600V_80K_1.dat"]
roomtemp_anneal2_1_data_Cs =  make_df_from_dat(roomtemp_anneal2_1_Cs, 530, 700)
roomtemp_anneal2_2_Cs = ["roomtemp_anneal2/20241009_Cs137_AC_600V_80K_2.dat"]
roomtemp_anneal2_2_data_Cs =  make_df_from_dat(roomtemp_anneal2_2_Cs, 530, 700)
roomtemp_anneal2_Cs = ["roomtemp_anneal2/20241009_Cs137_AC_600V_80K_1.dat", "roomtemp_anneal2/20241009_Cs137_AC_600V_80K_2.dat"]
roomtemp_anneal2_data_Cs =  make_df_from_dat(roomtemp_anneal2_Cs, 530, 700)

# %%
#adjust which data set you are fitting here 

pre_rad_data = pre_rad_data_Cs
#pre rad AC and DC strips
pre_rad_ACstrips = pre_rad_data.iloc[:,3]
pre_rad_DCstrips = pre_rad_data.iloc[:,6]
pre_rad_DCstripID = pre_rad_data.iloc[:,5]

# %%
#post rad1 AC and DC strips
post_rad1_ACstrips = post_rad1_data_Cs.iloc[:,3]
post_rad1_DCstrips = post_rad1_data_Cs.iloc[:,6]
post_rad1_DCstripID = post_rad1_data_Cs.iloc[:,5]
#post rad2 AC and DC strips
post_rad2_ACstrips = post_rad2_data_Cs.iloc[:,3]
post_rad2_DCstrips = post_rad2_data_Cs.iloc[:,6]
#post anneal 1 AC and DC strips
post_anneal1_ACstrips = post_anneal1_data_Cs.iloc[:,3]
post_anneal1_DCstrips = post_anneal1_data_Cs.iloc[:,6]
post_anneal1_DCstripID = post_anneal1_data_Cs.iloc[:,5]

#post anneal 2 AC and DC strips
post_anneal2_ACstrips = post_anneal2_data_Cs.iloc[:,3]
post_anneal2_DCstrips = post_anneal2_data_Cs.iloc[:,6]
#post anneal 3 AC and DC strips
post_anneal3_ACstrips = post_anneal3_data_Cs.iloc[:,3]
post_anneal3_DCstrips = post_anneal3_data_Cs.iloc[:,6]
#post anneal 4 AC and DC strips
post_anneal4_ACstrips = post_anneal4_data_Cs.iloc[:,3]
post_anneal4_DCstrips = post_anneal4_data_Cs.iloc[:,6]
post_anneal4_DCstripID = post_anneal4_data_Cs.iloc[:,5]
#post anneal 5 AC and DC strips
post_anneal5_ACstrips = post_anneal5_data_Cs.iloc[:,3]
post_anneal5_DCstrips = post_anneal5_data_Cs.iloc[:,6]
post_anneal5_DCstripID = post_anneal5_data_Cs.iloc[:,5]
#post anneal 6 AC and DC strips
post_anneal6_ACstrips = post_anneal6_data_Cs.iloc[:,3]
post_anneal6_DCstrips = post_anneal6_data_Cs.iloc[:,6]
post_anneal6_DCstripID = post_anneal6_data_Cs.iloc[:,5]
#post anneal 7 AC and DC strips
post_anneal7_ACstrips = post_anneal7_data_Cs.iloc[:,3]
post_anneal7_DCstripID = post_anneal7_data_Cs.iloc[:,5]
post_anneal7_DCstrips = post_anneal7_data_Cs.iloc[:,6]

#room temp anneal 2 AC and DC strips
roomtemp_anneal2_1_ACstrips = roomtemp_anneal2_1_data_Cs.iloc[:,3]
roomtemp_anneal2_1_DCstrips = roomtemp_anneal2_1_data_Cs.iloc[:,6]
roomtemp_anneal2_2_ACstrips = roomtemp_anneal2_2_data_Cs.iloc[:,3]
roomtemp_anneal2_2_DCstrips = roomtemp_anneal2_2_data_Cs.iloc[:,6]
roomtemp_anneal2_ACstrips = roomtemp_anneal2_data_Cs.iloc[:,3]
roomtemp_anneal2_DCstrips = roomtemp_anneal2_data_Cs.iloc[:,6]

# %%
#room temp anneal AC and DC strips
roomtemp_anneal_ACstrips = roomtempanneal_data_Cs.iloc[:,3]
roomtemp_anneal_DCstrips = roomtempanneal_data_Cs.iloc[:,6]
roomtemp_anneal_DCstripID = roomtempanneal_data_Cs.iloc[:,5]

# %%
strip_sort(post_anneal7_DCstrips, post_anneal7_DCstripID)
strip_spectra(post_anneal7_DCstrips,  post_anneal7_DCstripID)
# Out:
# /var/folders/g9/70rty0x929vfgjpdhdclnn7m0000gq/T/ipykernel_92640/833239175.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# weird_anneal6_Cs = ["postanneal6_dats/20240513_Cs137_AC_600V.dat"] #, "postanneal6_dats/20240513_Cs137_AC_600V.dat"
# weird_anneal6_data_Cs = make_df_from_dat(weird_anneal6_Cs, 600, 700)
# weird_anneal6_ACstrips = weird_anneal6_data_Cs.iloc[:,3]
# weird_anneal6_DCstrips = weird_anneal6_data_Cs.iloc[:,6]

# plot(weird_anneal6_DCstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf,"weird anneal 6 data ")

# %%
#plot change in  FWHM for Cs137



FWHMs =[ anneal2[0], anneal3[0], anneal4[0], anneal5[0], anneal6[0], anneal7[0]] #FWHM are from spline fits 
print(FWHMs)
times = [ 0, 24, 72, 168, 360, 552]
labels =[ "Anneal 2", "Anneal 3", "Anneal 4", "Anneal 5", "Anneal 6", "Anneal 7"]

plt.scatter(times, FWHMs, marker="*")
plt.axhline(y = prerad[0], color = 'green', linestyle = '--', label = "Pre-rad") 
plt.axhline(y = postrad2[0], color = 'red', linestyle = '--', label = "Post-rad") 

for i, label in enumerate(labels):
    plt.text(times[i]+10, FWHMs[i]+0.75, label, ha='right', fontsize=11)


#calculate errors 
N= [len(post_anneal2_DCstrips), len(post_anneal3_DCstrips), len(post_anneal4_DCstrips), len(post_anneal5_DCstrips), len(post_anneal6_DCstrips),len(post_anneal7_DCstrips) ]
err = []
for i in range(len(FWHMs)):
    err.append(FWHMs[i]/np.sqrt(2*N[i]))

print(err)

plt.errorbar(times, FWHMs, yerr=err, fmt=".", ecolor='green')


plt.title("Cs-137 FWHM for Hole-Collecting Strips", fontsize=16)
plt.ylabel("FWHM (keV)", fontsize=12)
plt.xlabel("Time at 100$^{\circ}$C (hours)", fontsize = 12)
plt.legend()
plt.grid(True)

#plt.ylim(0,30)
# Out:
# [np.float64(21.431327098011252), np.float64(19.376482180534367), np.float64(17.519101709235997), np.float64(7.524729408207463), np.float64(3.705031464655576), np.float64(3.104504722069123)]
# [np.float64(0.0607673499007471), np.float64(0.06809042533559975), np.float64(0.04216613180477511), np.float64(0.020660486035238325), np.float64(0.007863243412406193), np.float64(0.0131431231043669)]

# %%
#plot trapping FWHM

FWHM_trap =[]

FWHM_preRad= prerad[0]

for i in FWHMs:
    FWHM_trap.append(np.sqrt(i**2-FWHM_preRad**2))

FWHM_trap_array = np.array(FWHM_trap)
print(FWHM_trap)
times = np.array([0, 24, 72, 168, 360, 552])
labels =["Anneal 2", "Anneal 3", "Anneal 4", "Anneal 5", "Anneal 6", "Anneal 7"]

plt.scatter(times, FWHM_trap_array, marker=".")
#plt.axhline(y = 3.06, color = 'r', linestyle = '--', label = "Pre-rad FWHM") 

for i, label in enumerate(labels):
    plt.text(times[i], FWHM_trap[i], label, ha='right')


#calculate errors 
#N= [len(post_anneal2_DCstrips), len(post_anneal3_DCstrips), len(post_anneal4_DCstrips), len(post_anneal5_DCstrips), len(post_anneal6_DCstrips)]
err = []
#for i in range(len(FWHM_trap)):
#    err.append(FWHM_trap[i]/np.sqrt(2*N[i]))

#print(err)
#plt.errorbar(times, FWHM_trap, yerr=err, fmt=".")





plt.title("Cs-137 $FWHM_{rad}$  vs. Time Annealing", fontsize=14)
plt.ylabel("$FWHM_{rad}$  (keV)", fontsize=12)
plt.xlabel("Time at 100$^{\circ}$C (hours)", fontsize = 12)
plt.legend()
#plt.yscale('log')
plt.grid(True)

print(FWHM_trap)
# Out:
# [np.float64(21.211047250188205), np.float64(19.13255879281), np.float64(17.248932400769647), np.float64(6.872284695391151), np.float64(2.081826703127102), np.float64(0.4946653789327664)]
# [np.float64(21.211047250188205), np.float64(19.13255879281), np.float64(17.248932400769647), np.float64(6.872284695391151), np.float64(2.081826703127102), np.float64(0.4946653789327664)]
# /var/folders/g9/70rty0x929vfgjpdhdclnn7m0000gq/T/ipykernel_53350/572606078.py:38: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# FWHM_extra=[ postrad1[0], postrad2[0], roomtemp_anneal[0], anneal1[0]] #FWHM are from spline fits 
# FWHM_trap_ex =[]

# FWHM_preRad= prerad[0]
# for i in FWHM_extra:
#     FWHM_trap_ex.append(np.sqrt(i**2-FWHM_preRad**2))

# FWHM_trap_ex_array = np.array(FWHM_trap_ex)
# print(FWHM_trap_ex)
# print(roomtemp_anneal[0])

# %%
#plot change in  trapping length for Cs137
plots=[anneal2, anneal3, anneal4, anneal5, anneal6]
rad_trapping_lens =[]
for i in plots:
    rad_trapping_lens.append(trapping_len(prerad,i))
    
print(plots)
times = [0, 24, 72, 168, 360]
labels =["Anneal 2", "Anneal 3", "Anneal 4", "Anneal 5", "Anneal 6"]

# Define the time points and corresponding values (you can replace these with your actual data)
t_data = np.array(times)  # Time points
y_data = np.array(rad_trapping_lens)  # Corresponding values

# Input initial guess parameters for the exponential decay fit
initial_guess = [30, -100]  # A, tau, C

# Fit the data to the exponential decay function
popt, pcov = curve_fit(exponential_decay, t_data, y_data, p0=initial_guess)

# Extract fitted parameters
A_fit, tau_fit = popt


t_continuous = np.linspace(0, 600, 100)  # Continuous time points for plotting
y_continuous = exponential_decay(t_continuous, A_fit, tau_fit)

plt.scatter(times, rad_trapping_lens)
#plt.axhline(y = 37*1.5, color = 'r', linestyle = '--', label = "detector thickness") 
#plot fit
plt.plot(t_continuous, y_continuous, 'g-', label='Exponential Fit')

for i, label in enumerate(labels):
    plt.text(times[i], rad_trapping_lens[i], label, ha='right')

plt.title("Cs-137 Trapping Length")
plt.ylabel("Trapping Length (cm)")
plt.xlabel("Time at 100C (hours)")
plt.legend()
plt.grid(True)
print("Time Constant: " + str(tau_fit))
# Out:
# [(np.float64(21.431327098011252), np.float64(68.04265442827534)), (np.float64(19.376482180534367), np.float64(47.0577904659516)), (np.float64(17.519101709235997), np.float64(30.869146157159093)), (np.float64(7.524729408207463), np.float64(16.88254647941028)), (np.float64(3.705031464655576), np.float64(11.699654348417084))]
# Time Constant: -151.6242167366235

# %%
# #separate data set for AC and DC strips:

# #adjust which illumination you are choosing here 
# post_anneal1_data_Cs = post_anneal1_data_Cs_AC
# post_anneal2_data_Cs = post_anneal2_data_Cs_AC
# post_anneal3_data_Cs = post_anneal3_data_Cs_AC
# post_anneal4_data_Cs = post_anneal4_data_Cs_AC
# post_anneal5_data_Cs = post_anneal5_data_Cs_AC
# #post_anneal6_data_Cs = post_anneal6_data_Cs_AC

# post_rad1_data_Cs = post_rad1_data_Cs_AC
# post_rad2_data_Cs = post_rad2_data_Cs_AC
# pre_rad_data = pre_rad_data_Cs_AC

# #pre rad AC and DC strips
# pre_rad_ACstrips = pre_rad_data.iloc[:,3]
# pre_rad_DCstrips = pre_rad_data.iloc[:,5]
# #post rad1 AC and DC strips
# post_rad1_ACstrips = post_rad1_data_Cs.iloc[:,3]
# post_rad1_DCstrips = post_rad1_data_Cs.iloc[:,5]
# #post rad2 AC and DC strips
# post_rad2_ACstrips = post_rad2_data_Cs.iloc[:,3]
# post_rad2_DCstrips = post_rad2_data_Cs.iloc[:,5]
# #post anneal 1 AC and DC strips
# post_anneal1_ACstrips = post_anneal1_data_Cs.iloc[:,3]
# post_anneal1_DCstrips = post_anneal1_data_Cs.iloc[:,6]
# #post anneal 2 AC and DC strips
# post_anneal2_ACstrips = post_anneal2_data_Cs.iloc[:,3]
# post_anneal2_DCstrips = post_anneal2_data_Cs.iloc[:,5]
# #post anneal 3 AC and DC strips
# post_anneal3_ACstrips = post_anneal3_data_Cs.iloc[:,3]
# post_anneal3_DCstrips = post_anneal3_data_Cs.iloc[:,5]
# #post anneal 4 AC and DC strips
# post_anneal4_ACstrips = post_anneal4_data_Cs.iloc[:,3]
# post_anneal4_DCstrips = post_anneal4_data_Cs.iloc[:,6]
# #post anneal 5 AC and DC strips
# post_anneal5_ACstrips = post_anneal5_data_Cs.iloc[:,3]
# post_anneal5_DCstrips = post_anneal5_data_Cs.iloc[:,5]
# #post anneal 6 AC and DC strips
# #post_anneal6_ACstrips = post_anneal6_data_Cs.iloc[:,3]
# #post_anneal6_DCstrips = post_anneal6_data_Cs.iloc[:,5]

#room temp anneal AC and DC strips
# roomtemp_anneal_ACstrips_AC = roomtempanneal_Cs_data_AC.iloc[:,3]
# roomtemp_anneal_DCstrips_AC = roomtempanneal_Cs_data_AC.iloc[:,6]
# roomtemp_anneal_ACstrips_DC = roomtempanneal_Cs_data_DC.iloc[:,3]
# roomtemp_anneal_DCstrips_DC = roomtempanneal_Cs_data_DC.iloc[:,6]

# %%
# roomtemp_anneal_AC=plot(roomtemp_anneal_DCstrips_AC,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf,"Room Temperature Anneal-- Cs-137 DC strips AC illumination")
# roomtemp_anneal_DC =plot(roomtemp_anneal_DCstrips_DC,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf,"Room Temperature Anneal-- Cs-137 DC strips DC illumination")

# %%
#plot FWTM/ FWHM across anneals
#not super helpful metric here ??

#FWTM_FWHM =[anneal2[1]/anneal2[0], anneal3[1]/anneal3[0], anneal4[1]/anneal4[0], anneal5[1]/anneal5[0], anneal6[1]/anneal6[0], anneal7[1]/anneal7[0]]
#print(len(FWTM_FWHM), len(times))
#plt.scatter(times, FWTM_FWHM)
#plt.title("FWTM/FWTM vs. Time Annealing at 100 C")
#plt.xlabel("Time at 100C (hr)")
#plt.ylabel("FWTM/FWHM")

# %%
# all_energy_array = [roomtemp_anneal_DCstrips, post_anneal1_DCstrips, post_anneal2_DCstrips, post_anneal3_DCstrips, post_anneal4_DCstrips, post_anneal5_DCstrips, post_anneal6_DCstrips, post_anneal7_DCstrips]
# all_exposure_times = [ 1088,380, 176, 117, 243, 183, 236, 80] #in minutes 
# all_label_array = ["room temp", "anneal 1", "anneal 2", "anneal 3", "anneal 4", "anneal 5", "anneal 6", "anneal 7"]
# min_energy= 400.0

# # Q_factor = multi_spline(all_energy_array, min_energy,  all_exposure_times, all_label_array, colors, colordefault=True) 
# # print(Q_factor)
# # tot_anneal_times = [0, 24, 48, 72, 120, 216, 408, 600]

# plt.scatter(tot_anneal_times, Q_factor, marker =".")
# plt.title("Q-factor vs. time annealing")
# plt.xlabel("Time High Temp Annealing (hr)")
# plt.ylabel("Q-factor (keV $\cdot$ mins / counts)")
# for i, label in enumerate(all_label_array):
#     plt.text(tot_anneal_times[i], Q_factor[i], label, ha='right')

# plt.axhline(0, color='r', lw=1)

# %%
#exposure times for anneals 2-7 

# exposure_times_100C = [ 1057, 176, 117, 243, 183, 236, 80, 142] #in minutes 
# energy_array_100C = [pre_rad_DCstrips, post_anneal2_DCstrips, post_anneal3_DCstrips, post_anneal4_DCstrips, post_anneal5_DCstrips, post_anneal6_DCstrips, post_anneal7_DCstrips, roomtemp_anneal2_DCstrips]
# min_energy = 550.0
# label_array_100C = [ "pre radiation", "anneal 2", "anneal 3", "anneal 4", "anneal 5", "anneal 6", "anneal 7", "room temp 2"]
# colors = [  "black", "green", "blue", "deepskyblue", "cyan", 'purple',"magenta",  "red"] 
# multi_spline(energy_array_100C, min_energy,  exposure_times_100C, label_array_100C, colors)

# %%
# all_energy_array = [pre_rad_DCstrips, post_rad1_DCstrips, post_rad2_DCstrips, roomtemp_anneal_DCstrips, post_anneal1_DCstrips, post_anneal2_DCstrips, post_anneal3_DCstrips, post_anneal4_DCstrips, post_anneal5_DCstrips, post_anneal6_DCstrips, post_anneal7_DCstrips]
# all_exposure_times = [1057, 2308, 1618, 1088,380, 176, 117, 243, 183, 236, 80] #in minutes 
# all_label_array = ["pre radiation", "radiation 1", "radiation 2", "room temp", "anneal 1", "anneal 2", "anneal 3", "anneal 4", "anneal 5", "anneal 6", "anneal 7"]
# min_energy= 560.0

# multi_spline(all_energy_array, min_energy,  all_exposure_times, all_label_array, colors, colordefault=True) 

# anneal_energy_array = [pre_rad_DCstrips, post_anneal1_DCstrips, post_anneal2_DCstrips, post_anneal3_DCstrips, post_anneal4_DCstrips, post_anneal5_DCstrips, post_anneal6_DCstrips, post_anneal7_DCstrips]
# anneal_exposure_times = [1057, 380, 176, 117, 243, 183, 236, 80] #in minutes 
# anneal_label_array = ["Pre Radiation", "Anneal 1", "Anneal 2", "Anneal 3", "Anneal 4", "Anneal 5", "Anneal 6", "Anneal 7"]

# multi_spline(anneal_energy_array, min_energy,  anneal_exposure_times, anneal_label_array, colors)

# %%
all_anneal_array = [pre_rad_DCstrips,  post_anneal1_DCstrips, post_anneal2_DCstrips, post_anneal3_DCstrips, post_anneal4_DCstrips, post_anneal5_DCstrips, post_anneal6_DCstrips, post_anneal7_DCstrips]
all_anneal_times = [1057,380, 176, 117, 243, 183, 236, 80] #in minutes 
all_label_array = ["Preradiation", "Anneal 1", "Anneal 2", "Anneal 3", "Anneal 4", "Anneal 5", "Anneal 6", "Anneal 7"]
min_energy= 570.0

cmap =sns.color_palette("husl", 7)
colors=["black"]+cmap
multi_spline(all_anneal_array, min_energy,700,  all_anneal_times, all_label_array,colors, colordefault=False)

# %%
energy_array=[ roomtemp_anneal_DCstrips ]
bin_num_array = []
min_energy=350
colors =['#1f77b4']
label_array=["Room Temperature Anneal"]

multi_spline(energy_array, 440, 675,0, 0.6, [1088], label_array, colors, colordefault=False, vline=True) 
#plt.axvline(661.7, ls ="--", color = '#ff7f0e', lw=3)

# %%
# energy_array=[pre_rad_DCstrips, post_anneal6_DCstrips, post_anneal7_DCstrips]
# min_energy=600

# exposure_times = [1057,236, 60]
# label_array=["pre rad", "anneal 6", "anneal 7"]

# multi_spline(energy_array, min_energy, exposure_times,  label_array, colors, colordefault=True)

# %%
# energy_array = [ post_anneal6_DCstrips, weird_anneal6_DCstrips, pre_rad_DCstrips,]
# exposure_times = [ 84, 236, 1057] #in minutes 
# label_array = [ "Anneal 6: 5/03", "Anneal 6: 5/13", "pre rad"]
# bin_num_array = []
# for i in energy_array:
#     bin = int((np.max(i)-np.min(i)))*4
#     bin_num_array.append(bin)
# min_energy= 560.0
# multi_spline(energy_array, min_energy, bin_num_array, exposure_times, label_array, "combined spline plots")

# %%
rad_energy_array=[pre_rad_DCstrips, post_rad1_DCstrips, post_rad2_DCstrips, roomtemp_anneal_DCstrips]
min_energy = 550.0

colors = [ "black", '#d62728','#ff7f0e','#1f77b4']#'#1f77b4']
rad_exposure_times= [1057, 2308, 1618, 1088]
rad_label_array=["Preradiation", "Radiation 1", "Radiation 2", "Room Temperature Anneal"]

multi_spline(rad_energy_array, min_energy, rad_exposure_times, rad_label_array, colors, colordefault=False, log =True)
# Out:
# Q-factor for Preradiation 70.72749744355446
# Q-factor for Radiation 1 88.24622007307674
# Q-factor for Radiation 2 60.89261613349506
# Q-factor for Room Temperature Anneal 158.0113366407871
# [70.72749744355446, 88.24622007307674, 60.89261613349506, 158.0113366407871]

# %%
#assume that the ratio of primary defects (exp 1) to secondary defects(exp 2) is 50:140 
#and that the secondary defects anneal out at 100X the rate of the primary defects
times1 = [0, 24, 72]
times2 = [ 0, 24, 72, 168, 360, 552]
#100C
energy1 = [168.07,38.11, 21.11]
#find just the radiation induced fwhm
energies80C=[]
for i in energy1:
    energies80C.append(np.sqrt(i**2-2.27**2))

#primary_pop = 20
#secondary_pop=130
primary_rate = 1000
secondary_rate = 10
guess1 = [ 1/primary_rate, 1/secondary_rate, 21, 147]

fit_and_plot_double_exponential(times1,energies80C, guess1, " ")
# Out:
# tau1 = 5895.53305007531
# tau2 = 11.16029266634781
# A1 = 21.010325606344125
# A2 = 147.0266356470212
# errors:[inf inf inf inf]
# /Users/Sophie/Desktop/COSI/calibrations/Data/CalibratedDATs/plotting_helper.py:437: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, covariance = curve_fit(double_exponential, x_data, y_data, p0=initial_guess, bounds=bounds)
# (0.00016961994640793778, 0.08960338495560695)

# %%
guessfixed= [ 1/11, 147]
fit_and_plot_double_exponential_fixed(times1,energies80C, guessfixed, "Double Exponential Fit to 80$^{\circ}$C Anneals")

# %%
fit_and_plot_double_exponential(times1,energies80C, guess1, "Double Exponential Fit to 80$^{\circ}$C Anneals")
fit_and_plot_double_exponential_fixed(times1,energies80C, guessfixed, "Double Exponential Fit to 80$^{\circ}$C Anneals")

# %%
plt.plot([0, 7.3e7, 1.9e8, 2.6e8, 5.7e8],[2.3, 2.6, 3.6, 3.9, 8.5])

# %%
#assume most secondary defects are now annealed out
#and use the same rates as we find for the 80C anneals
primary_pop = 15
secondary_pop=6
primary_rate = fit_and_plot_double_exponential(times1,energy1, guess1, "80C Anneals")[0]

secondary_rate = fit_and_plot_double_exponential(times1,energy1, guess1, "80C Anneals")[1]
print("rates:", primary_rate, secondary_rate)

guess2 = [ primary_rate, secondary_rate, primary_pop, secondary_pop]

fit_and_plot_double_exponential(times2,energies100C, guess2, "Double Exponential Fit to 100$^{\circ}$C Anneals")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 5
#       3 primary_pop = 15
#       4 secondary_pop=6
# ----> 5 primary_rate = fit_and_plot_double_exponential(times1,energy1, guess1, "80C Anneals")[0]
#       7 secondary_rate = fit_and_plot_double_exponential(times1,energy1, guess1, "80C Anneals")[1]
#       8 print("rates:", primary_rate, secondary_rate)
#
# NameError: name 'times1' is not defined

# %%
fit_and_plot_double_exponential_fixed(times2,energies100C, [primary_rate, secondary_rate], "Double Exponential Fit to 100$^{\circ}$C Anneals")
# Out:
# [0.0054926  0.12796635]
# tau1 = 182.0630284864151
# tau2 = 7.8145541917889645
# errors:[0.00080041 0.        ]
# (0.005492603349035339, 0.12796635296876388)

# %%
#redefine 100c and 80C datasets

#100C
energy1 = [168.07,38.11, 21.11]
#find just the radiation induced fwhm
energies80C=[]
for i in energy1:
    energies80C.append(np.sqrt(i**2-2.27**2))

print(energy1, energies80C)
    
energy2 = [ anneal2[0], anneal3[0], anneal4[0], anneal5[0], anneal6[0], anneal7[0]]
energies100C=[]
for i in energy2:
    energies100C.append(np.sqrt(i**2-FWHM_preRad**2))

times1 = [0, 24, 72]
times2 = [ 0, 24, 72, 168, 360, 552]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       6 energies80C=[]
#       7 for i in energy1:
# ----> 8     energies80C.append(np.sqrt(i**2-FWHM_preRad**2))
#      10 print(energy1, energies80C)
#      12 energy2 = [ anneal2[0], anneal3[0], anneal4[0], anneal5[0], anneal6[0], anneal7[0]]
#
# NameError: name 'FWHM_preRad' is not defined

# %%
#PRE RAD
#AC STRIPS
#plot(pre_rad_ACstrips, 630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Pre Radiation -- Cs-137 AC strips")

# %%
#PRE RAD
#DC STRIP
#plot(pre_rad_DCstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Pre Radiation -- Cs-137 DC strips")
#AC STRIP
#plot(pre_rad_ACstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Pre Radiation -- Cs-137 AC strips")

# %%
#POST RAD 1
#AC STRIPS
#plot(post_rad1_ACstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Post Rad 1-- Cs-137 AC strips")

# %%
#POST RAD 1
#DC STRIPS
#trapping_len(preRad_plot,plot(post_rad1_DCstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Rad 1 -- Cs-137 DC strips"))

# %%
#POST RAD 2 
#AC STRIPS
#plot(post_rad2_ACstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Rad 2-- Cs-137 AC strips")

# %%
#POST RAD 2 
#DC STRIPS
#trapping_len(preRad_plot,plot(post_rad2_DCstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Rad 2-- Cs-137 DC strips"))

# %%
#POST ANNEAL 1
#AC STRIPS
#plot(post_anneal1_ACstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Anneal 1-- Cs-137 AC strips")

# %%
#POST ANNEAL 1
#DC STRIPS
#trapping_len(preRad_plot,plot(post_anneal1_DCstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Anneal 1-- Cs-137 DC strips"))

# %%
#POST ANNEAL 2
#AC STRIPS
#plot(post_anneal2_ACstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Anneal 2-- Cs-137 AC strips")

# %%
#POST ANNEAL 2
#DC STRIPS
#trapping_len(preRad_plot,plot(post_anneal2_DCstrips,630.0, 680.00, 662.0, gauss_plus_tail_depth, gauss_plus_tail_pdf, "Post Anneal 2-- Cs-137 DC strips"))

# %%
#POST ANNEAL 3
#DC STRIPS
#trapping_len(preRad_plot,plot(post_anneal3_DCstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Post Anneal 3-- Cs-137 DC strips"))
#AC strips 
#preRad_plot,plot(post_anneal3_ACstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Post Anneal 3-- Cs-137 AC strips")

# %%
#POST ANNEAL 4
#DC STRIPS
#trapping_len(preRad_plot,plot(post_anneal4_DCstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Post Anneal 4-- Cs-137 DC strips"))
#AC strips 
#plot(post_anneal4_ACstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Post Anneal 4-- Cs-137 AC strips")

# %%
#POST ANNEAL 5
#DC STRIPS
#trapping_len(preRad_plot,plot(post_anneal5_DCstrips,630.0, 680.00, 662.0, gauss_minus_linear_tail_depth, gauss_minus_linear_tail_pdf, "Post Anneal 5-- Cs-137 DC strips"))
